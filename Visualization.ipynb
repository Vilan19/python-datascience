# %% [markdown]
# <a href="https://colab.research.google.com/github/Vilan19/python-datascience/blob/main/Copy_of_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib

# %% [markdown]
# Reference :
#
# https://matplotlib.org/stable/gallery/index.html

# %% [markdown]
# ## Intro

# %%
# import module
import matplotlib.pyplot as plt

# %%
# create data

x = [1, 2, 3]
y = [2, 4, 6]
z = ['enak', 'tidak enak', 'kurang enak']

# %%
# menggambar grafik line
plt.plot(x, y)

# tampilkan grafik
plt.show()

# %%
# menggambar grafik batang

plt.bar(x, y)
plt.show()

# %%
# menggambar grafik pie
plt.pie(x, labels=z)
plt.show()

# %%
# menggambar grafik box
plt.boxplot(x)
plt.show()

# %%
# menggambar grafik scatter
plt.scatter(x, y)
plt.show()

# %%
# matplotlib with numpy data

import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
# add label
plt.plot(xpoints, ypoints)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
# subplot

plt.subplot(1, 2, 1) #(1baris, 1kolom, index)
plt.plot(x,y)

plt.subplot(1, 2, 2)
plt.plot(xpoints, ypoints)


plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.bar(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.boxplot(x)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.pie(y, labels=['A', 'B', 'C', 'D'])

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.barh(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.scatter(x,y)

plt.show()

# %% [markdown]
# ## Line Chart

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Create a random number
random = []
for _ in range(50):
  random.append(np.random.randint(1, 100))

# Create a dataframe format and save a random number inside
df = pd.DataFrame(random, columns = ['tes1'])
df
# df.head(20)
# df.tail()
# Out:
#     tes1
# 0      7
# 1     58
# 2     38
# 3     74
# 4     62
# 5     35
# 6     91
# 7     71
# 8     60
# 9     93
# 10    88
# 11    89
# 12     4
# 13     4
# 14     7
# 15    23
# 16    56
# 17     5
# 18    24
# 19    25
# 20    41
# 21    19
# 22    49
# 23    45
# 24    58
# 25    33
# 26    95
# 27    45
# 28    47
# 29    66
# 30    22
# 31     1
# 32    55
# 33    41
# 34    10
# 35    27
# 36    53
# 37     8
# 38    78
# 39    75
# 40    98
# 41    33
# 42    16
# 43    54
# 44    42
# 45    66
# 46    26
# 47    49
# 48    71
# 49    54

# %%
# Create a single line chart
plt.figure(figsize = (10, 5)) # ukuran canvas(p,l)
plt.plot(df['tes1'], marker = 'P') # definiskan dataframe
plt.title('Single Line Chart with Random Numbers') # judul chart
plt.xticks(df.index) # skala X berdasarkan index baris
plt.xlabel('Row') # memberi label pada X
plt.ylabel('Random Numbers') # memberi label pada Y
# Out:
# Text(0, 0.5, 'Random Numbers')

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

# data_df
plt.figure(figsize = (20, 5))
plt.plot(xpoints, ypoints)
plt.title('Single Line Chart with Random Numbers')
plt.xlabel('X Points')
plt.ylabel('Y Points')
# Out:
# Text(0, 0.5, 'Y Points')

# %%
# Create an another random number
random2 = []
for _ in range(50):
  random2.append(np.random.randint(1, 100))
df['tes 2'] = random2

# Create a multiple line chart
plt.figure(figsize = (10, 5))
plt.plot(df['tes1'], label = 'Random')
plt.plot(df['tes 2'], label = 'Random 2', color = 'brown')
plt.title('Multiple Line Chart with Random Numbers')
plt.xlabel('Row')
plt.ylabel('Random Numbers')
plt.legend(loc = 'upper left') # Must set label first in plt.plot()
plt.show()

# %% [markdown]
# ## Bar Chart

# %%
# Data preparation
x_value = ['A', 'B', 'C', 'D', 'E']
y_value = []
for _ in x_value:
  y_value.append(np.random.randint(10, 50))
df = pd.DataFrame({'Nilai X' : x_value, 'Nilai Y' : y_value})


# Create a bar chart
plt.figure(figsize = (15, 8))
plt.bar(df['Nilai X'], df['Nilai Y'])
plt.title('Frequency of Each Alphabet')
plt.xticks(df['Nilai X']) #panjang dari x
plt.yticks(np.arange(0, 51, step = 10)) #panjang dari y
plt.xlabel('Nilai X')
plt.ylabel('Nilai Y')
plt.show()

# %%
# Horizontal Bar Chart
plt.figure(figsize = (20, 8))
plt.barh(df['Nilai X'], df['Nilai Y'], color='r', height = 0.5)
plt.title('Frequency of Each Alphabet')
plt.yticks(df['Nilai X'])
plt.xticks(np.arange(0, 51, step = 10))
plt.xlabel('Nilai Y')
plt.ylabel('Nilai X')
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
# Data preparation
perc = [20, 15, 40, 25]
mylabel = ['A', 'B', 'C', 'D']
# Create a pie chart
plt.figure(figsize = (10, 5))
plt.pie(perc, labels = mylabel, autopct = '%1.1f%%') #autopct: value yg mau didalamnya mau brp angka dibelakang koma
plt.title('Percentage of Alphabet')
plt.show()

# %%
# Pie chart explode
nilai = [20, 15, 40, 25]
pielabel = ["Apples", "Bananas", "Cherries", "Dates"]
nilai_explode = [0, 0, 0.1, 0]

# Create a pie chart
plt.figure(figsize = (10, 5))
plt.pie(nilai, labels = pielabel, autopct = '%1.1f%%', explode = nilai_explode)
plt.title('Percentage of Alphabet')
plt.show()

# %%
# Pie chart colors
nilai = [20, 15, 40, 25]
pielabel = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["orange", "brown", "b", "#4CAF50"]

# Create a pie chart
plt.figure(figsize = (10, 5))
plt.pie(nilai, labels = pielabel, autopct = '%1.1f%%', colors = mycolors)
plt.title('Percentage of Alphabet')
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Create a random number
nilai_x = []
for _ in range(50):
  nilai_x.append(np.random.randint(1, 100))
# Create a dataframe format and save a random number inside
df = pd.DataFrame(nilai_x, columns = ['Nilai X'])

nilai_y = []
for _ in range(50):
  nilai_y.append(np.random.randint(1, 100))
df['Nilai Y'] = nilai_y

#Scatter Plot
plt.figure(figsize = (20, 5))
plt.scatter(df['Nilai X'], df['Nilai Y'])
plt.xlabel('Nilai X')
plt.ylabel('Nilai Y')
# plt.grid()
plt.show()

# %%
#Scatter Plot one color
plt.figure(figsize = (20, 5))
plt.scatter(df['Nilai X'], df['Nilai Y'], color = '#88c999')
plt.xlabel('Nilai X')
plt.ylabel('Nilai Y')
plt.grid()
plt.show()

# %%
#Scatter Plot multiple color
mycolor = []
for _ in range(50):
  mycolor.append(np.random.randint(1, 100))

plt.figure(figsize = (20, 5))
plt.scatter(df['Nilai X'], df['Nilai Y'],  c=mycolor)
plt.xlabel('Nilai X')
plt.ylabel('Nilai Y')
plt.grid()
plt.colorbar()
plt.show()

# %% [markdown]
# # Seaborn

# %% [markdown]
# Reference :
#
# https://seaborn.pydata.org/examples/index.html

# %% [markdown]
# ## Intro

# %%
import numpy as np
import seaborn as sns

x = np.random.RandomState(10)
y = x.normal(size=100)

sns.lineplot(data=y)
# plt.show()
# Out:
# <Axes: >

# %% [markdown]
# ## Load dataset

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import pandas as pd

candy_data = pd.read_csv('/candy.csv')
candy_data
# Out:
#     id              competitorname chocolate fruity caramel peanutyalmondy  \
# 0    0                   100 Grand       Yes     No     Yes             No
# 1    1                3 Musketeers       Yes     No      No             No
# 2    2                   Air Heads        No    Yes      No             No
# 3    3                  Almond Joy       Yes     No      No            Yes
# 4    4                   Baby Ruth       Yes     No     Yes            Yes
# ..  ..                         ...       ...    ...     ...            ...
# 78  78                   Twizzlers        No    Yes      No             No
# 79  79                    Warheads        No    Yes      No             No
# 80  80        Welch's Fruit Snacks        No    Yes      No             No
# 81  81  Werther's Original Caramel        No     No     Yes             No
# 82  82                    Whoppers       Yes     No      No             No
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
sns.lineplot(data=candy_data, x=candy_data['sugarpercent'], y=candy_data['winpercent'])
# Out:
# <Axes: xlabel='sugarpercent', ylabel='winpercent'>

# %%
sns.barplot(data=candy_data, x = candy_data['caramel'], y = candy_data['pricepercent'])
plt.show()

# %%
import seaborn as sns
sns.scatterplot(x = candy_data['sugarpercent'], y = candy_data['winpercent'])
# Out:
# <Axes: xlabel='sugarpercent', ylabel='winpercent'>

# %%
sns.regplot(x = candy_data['sugarpercent'], y = candy_data['winpercent'])
# Out:
# <Axes: xlabel='sugarpercent', ylabel='winpercent'>

# %%
sns.scatterplot(x = candy_data['pricepercent'], y = candy_data['winpercent'], hue = candy_data['chocolate'])
# Out:
# <Axes: xlabel='pricepercent', ylabel='winpercent'>

# %%
sns.lmplot(x = 'pricepercent', y = 'winpercent', hue = 'chocolate', data = candy_data)

# %% [markdown]
# # Plotly

# %% [markdown]
# Reference :
#
# https://plotly.com/python/

# %% [markdown]
# ## Intro

# %%
import plotly.express as px


# Creating the Figure instance
fig = px.line(x=[1, 2, 3], y=[1, 2, 3])

# showing the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
fig = px.scatter(x=[0, 1, 2, 3, 4], y=[0, 1, 4, 9, 16])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly
import plotly.graph_objects as go

x = np.random.randint(low=1, high=50, size=150)*0.1

# generating 150 random integers
# from 1 to 50
y = np.random.randint(low=1, high=50, size=150)*0.1

# plotting scatter plot
fig = go.Figure(data=go.Scatter(x=x, y=y, mode='markers'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
data_canada = px.data.gapminder().query("country == 'Canada'")
fig = px.bar(data_canada, x='year', y='pop')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
countries=['India', 'canada',
           'Australia','Brazil',
           'Mexico','Russia',
           'Germany','Switzerland',
           'Texas']

# plotting corresponding y for each
# country in x
fig = go.Figure([go.Bar(x=countries,
                        y=[80,70,60,50,
                           40,50,60,70,80])])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
values = [4500, 2500, 1053, 500,
          3200, 1500, 1253, 600, 3500]

# plotting pie chart
fig = go.Figure(data=[go.Pie(labels=countries,
                      values=values)])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Load dataset

# %%
import pandas as pd
import plotly.express as px

df = px.data.tips()
# df.head()
# df.tail()
df.head(50)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
fig = px.box(df, y="total_bill")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(df, x="time", y="total_bill")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(df, x="day", y="total_bill", color="sex")
fig.show()

# dimension = day
# breakdown dimension = sex
# metric = total bill
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

long_df = px.data.medals_long()
long_df.head()
# Out:
#         nation   medal  count
# 0  South Korea    gold     24
# 1        China    gold     10
# 2       Canada    gold      9
# 3  South Korea  silver     13
# 4        China  silver     15

# %%
fig = px.bar(long_df, x="nation", y="count", color="medal", title="Long-Form Input")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = pd.DataFrame(dict(
    uas=[70, 85, 32, 92, 53],
    jurusan=['Akuntansi','Bisnis','Teknik Elektro',
           'Teknik Informatika', 'Matematika']))

fig = px.line_polar(df, r='uas', theta='jurusan', line_close=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.funnel(df, x='uas', y='jurusan')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Soal
#
# Download dataset berikut :
#
# https://drive.google.com/file/d/1rf9uzwFP6blI9OnLBl2Q3UyDD4O3cOqe/view?usp=drive_link
#
# * Buat project baru di colab
# * Load dataset
# * Lakukan visualisasi dengan matplotlib
# * Lakukan visualisasi dengan seaborn
# * Lakukan visualisasi dengan plotly

# %%
import pandas as pd
import matplotlib.pyplot as plt

banking_data = pd.read_csv('/content/drive/MyDrive/DATASET/banking.csv')
banking_data
# Out:
#        age          job  marital            education  default housing loan  \
# 0       44  blue-collar  married             basic.4y  unknown     yes   no
# 1       53   technician  married              unknown       no      no   no
# 2       28   management   single    university.degree       no     yes   no
# 3       39     services  married          high.school       no      no   no
# 4       55      retired  married             basic.4y       no     yes   no
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   59      retired  married          high.school  unknown      no  yes
# 41184   31    housemaid  married             basic.4y  unknown      no   no
# 41185   42       admin.   single    university.degree  unknown     yes  yes
# 41186   48   technician  married  professional.course       no      no  yes
# 41187   25      student   single          high.school       no      no   no
#
# ...

# %%
plt.figure(figsize=(10, 6))
# plt.hist(banking_data['age'], bins=30, color='blue', edgecolor='black')
plt.figure(figsize=(10, 6))
job_counts = banking_data['age'].value_counts()  # Menghitung jumlah nasabah berdasarkan pekerjaan
plt.bar(job_counts.index, job_counts.values, color='skyblue')
plt.title('UMUR PENGGUNA')
plt.xlabel('Umur')
plt.ylabel('Jumlah Nasabah')
plt.show()
